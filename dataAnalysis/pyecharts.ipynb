# %%
from pyecharts import charts

# %% [markdown]
# `https://www.cnblogs.com/adam012019/tag/Python/`

# %% [markdown]
# ## Bar(柱状图/条形图)

# %%
bar = charts.Bar()
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
# render 会生成本地 HTML 文件，默认会在当前目录生成 render.html 文件
# 也可以传入路径参数，如 bar.render("mycharts.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e33efb2ea0174467a0bb93c263f14493" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e33efb2ea0174467a0bb93c263f14493 = echarts.init(
#                     document.getElementById('e33efb2ea0174467a0bb93c263f14493'), 'white', {renderer: 'canvas'});
#                 var option_e33efb2ea0174467a0bb93c263f14493 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_e33efb2ea0174467a0bb93c263f14493.setOption(option_e33efb2ea0174467a0bb93c263f14493);
#         });
#     </script>

# %%
bar = charts.Bar()

bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
bar.add_yaxis("商家B", [15, 6, 45, 20, 35, 66])

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="75c9ba7a96cc437cb43cea588e82f08b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_75c9ba7a96cc437cb43cea588e82f08b = echarts.init(
#                     document.getElementById('75c9ba7a96cc437cb43cea588e82f08b'), 'white', {renderer: 'canvas'});
#                 var option_75c9ba7a96cc437cb43cea588e82f08b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 15,
#                 6,
#                 45,
#                 20,
#                 35,
#                 66
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_75c9ba7a96cc437cb43cea588e82f08b.setOption(option_75c9ba7a96cc437cb43cea588e82f08b);
#         });
#     </script>

# %%
from pyecharts.faker import Faker

# %%
Faker.choose()
# Out:
# ['草莓', '芒果', '葡萄', '雪梨', '西瓜', '柠檬', '车厘子']

# %%
Faker.values()
# Out:
# [131, 30, 137, 131, 90, 106, 104]

# %%
from pyecharts import options as opts

# %% [markdown]
# ### 基本示例

# %%
bar=(
    charts.Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bab44d8e8e694255ba8547a3a88b0f97" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bab44d8e8e694255ba8547a3a88b0f97 = echarts.init(
#                     document.getElementById('bab44d8e8e694255ba8547a3a88b0f97'), 'white', {renderer: 'canvas'});
#                 var option_bab44d8e8e694255ba8547a3a88b0f97 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 103,
#                 121,
#                 40,
#                 44,
#                 142,
#                 32,
#                 28
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 64,
#                 124,
#                 31,
#                 107,
#                 119,
#                 106,
#                 95
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_bab44d8e8e694255ba8547a3a88b0f97.setOption(option_bab44d8e8e694255ba8547a3a88b0f97);
#         });
#     </script>

# %% [markdown]
# ### 翻转 XY 轴

# %%
bar=(
    charts.Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="right"))
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-翻转 XY 轴"))
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="eb45f4b93e90482bbef98922e0eca808" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_eb45f4b93e90482bbef98922e0eca808 = echarts.init(
#                     document.getElementById('eb45f4b93e90482bbef98922e0eca808'), 'white', {renderer: 'canvas'});
#                 var option_eb45f4b93e90482bbef98922e0eca808 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 40,
#                 77,
#                 45,
#                 70,
#                 94,
#                 128,
#                 147
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 75,
#                 65,
#                 130,
#                 42,
#                 123,
#                 82,
#                 120
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u7ffb\u8f6c XY \u8f74",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_eb45f4b93e90482bbef98922e0eca808.setOption(option_eb45f4b93e90482bbef98922e0eca808);
#         });
#     </script>

# %% [markdown]
# ### 堆叠数据

# %%
from pyecharts.charts import Bar

# %%
bar=(
    Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), stack="stack1")
        .add_yaxis("商家B", Faker.values(), stack="stack1")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（全部）"))
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d8061e761d7547dfa40fcca2306a24f7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d8061e761d7547dfa40fcca2306a24f7 = echarts.init(
#                     document.getElementById('d8061e761d7547dfa40fcca2306a24f7'), 'white', {renderer: 'canvas'});
#                 var option_d8061e761d7547dfa40fcca2306a24f7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 41,
#                 142,
#                 142,
#                 39,
#                 149,
#                 135,
#                 73
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 37,
#                 130,
#                 104,
#                 49,
#                 129,
#                 64,
#                 73
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u5806\u53e0\u6570\u636e\uff08\u5168\u90e8\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d8061e761d7547dfa40fcca2306a24f7.setOption(option_d8061e761d7547dfa40fcca2306a24f7);
#         });
#     </script>

# %% [markdown]
# ### Bar-MarkPoint（指定类型）

# %%
bar=(
    Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-MarkPoint（指定类型）"))
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markpoint_opts=opts.MarkPointOpts(
                data=[
                    opts.MarkPointItem(type_="max", name="最大值"),
                    opts.MarkPointItem(type_="min", name="最小值"),
                    opts.MarkPointItem(type_="average", name="平均值"),
                ]
            ),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0f64fb631b9e4531a047b7ccd6b0a173" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0f64fb631b9e4531a047b7ccd6b0a173 = echarts.init(
#                     document.getElementById('0f64fb631b9e4531a047b7ccd6b0a173'), 'white', {renderer: 'canvas'});
#                 var option_0f64fb631b9e4531a047b7ccd6b0a173 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 133,
#                 67,
#                 48,
#                 137,
#                 62,
#                 114,
#                 33
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 88,
#                 111,
#                 79,
#                 112,
#                 135,
#                 123,
#                 115
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-MarkPoint\uff08\u6307\u5b9a\u7c7b\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0f64fb631b9e4531a047b7ccd6b0a173.setOption(option_0f64fb631b9e4531a047b7ccd6b0a173);
#         });
#     </script>

# %% [markdown]
# ### Bar-DataZoom（slider-水平）

# %%
bar=(
    Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
            datazoom_opts=opts.DataZoomOpts(),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f85bab9b13b1400789020892936204c8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f85bab9b13b1400789020892936204c8 = echarts.init(
#                     document.getElementById('f85bab9b13b1400789020892936204c8'), 'white', {renderer: 'canvas'});
#                 var option_f85bab9b13b1400789020892936204c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 4,
#                 30,
#                 20,
#                 19,
#                 2,
#                 10,
#                 4,
#                 2,
#                 30,
#                 27,
#                 10,
#                 19,
#                 23,
#                 24,
#                 8,
#                 22,
#                 21,
#                 6,
#                 27,
#                 29,
#                 7,
#                 15,
#                 28,
#                 5,
#                 11,
#                 4,
#                 14,
#                 24,
#                 10,
#                 5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#                 chart_f85bab9b13b1400789020892936204c8.setOption(option_f85bab9b13b1400789020892936204c8);
#         });
#     </script>

# %% [markdown]
# ### Bar-DataZoom（slider-垂直）

# %%
bar=(
    Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values, color=Faker.rand_color())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-垂直）"),
            datazoom_opts=opts.DataZoomOpts(orient="vertical"),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5089a061771e4b5082e7c74fb2702467" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5089a061771e4b5082e7c74fb2702467 = echarts.init(
#                     document.getElementById('5089a061771e4b5082e7c74fb2702467'), 'white', {renderer: 'canvas'});
#                 var option_5089a061771e4b5082e7c74fb2702467 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#f05b72",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 4,
#                 30,
#                 20,
#                 19,
#                 2,
#                 10,
#                 4,
#                 2,
#                 30,
#                 27,
#                 10,
#                 19,
#                 23,
#                 24,
#                 8,
#                 22,
#                 21,
#                 6,
#                 27,
#                 29,
#                 7,
#                 15,
#                 28,
#                 5,
#                 11,
#                 4,
#                 14,
#                 24,
#                 10,
#                 5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u5782\u76f4\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "vertical",
#         "zoomLock": false
#     }
# };
#                 chart_5089a061771e4b5082e7c74fb2702467.setOption(option_5089a061771e4b5082e7c74fb2702467);
#         });
#     </script>

# %% [markdown]
# ## Line

# %%
import pyecharts.options as opts
from pyecharts.charts import Line


x_data = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
y_data = [820, 932, 901, 934, 1290, 1330, 1320]


line = (
    Line()
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(is_show=False),
        xaxis_opts=opts.AxisOpts(type_="category"),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="",
        y_axis=y_data,
        symbol="emptyCircle",
        is_symbol_show=True,
        label_opts=opts.LabelOpts(is_show=False),
    )
)

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4e62d32fd8044887a5dd4b2c20efd694" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4e62d32fd8044887a5dd4b2c20efd694 = echarts.init(
#                     document.getElementById('4e62d32fd8044887a5dd4b2c20efd694'), 'white', {renderer: 'canvas'});
#                 var option_4e62d32fd8044887a5dd4b2c20efd694 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "Mon",
#                     820
#                 ],
#                 [
#                     "Tue",
#                     932
#                 ],
#                 [
#                     "Wed",
#                     901
#                 ],
#                 [
#                     "Thu",
#                     934
#                 ],
#                 [
#                     "Fri",
#                     1290
#                 ],
#                 [
#                     "Sat",
#                     1330
#                 ],
#                 [
#                     "Sun",
#                     1320
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Mon",
#                 "Tue",
#                 "Wed",
#                 "Thu",
#                 "Fri",
#                 "Sat",
#                 "Sun"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4e62d32fd8044887a5dd4b2c20efd694.setOption(option_4e62d32fd8044887a5dd4b2c20efd694);
#         });
#     </script>

# %% [markdown]
# ## 日历图 Calendar

# %%
import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar

# %%
begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [
        [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
        for i in range((end - begin).days + 1)
    ]

calendar=(
        Calendar()
        .add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
            visualmap_opts=opts.VisualMapOpts(
                max_=20000,
                min_=500,
                orient="horizontal",
                is_piecewise=True,
                pos_top="230px",
                pos_left="100px",
            ),
        )
    )

calendar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d17d7b62f1b64c8cbd22b46f7feaf1ef" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d17d7b62f1b64c8cbd22b46f7feaf1ef = echarts.init(
#                     document.getElementById('d17d7b62f1b64c8cbd22b46f7feaf1ef'), 'white', {renderer: 'canvas'});
#                 var option_d17d7b62f1b64c8cbd22b46f7feaf1ef = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2017-01-01",
#                     8847
#                 ],
#                 [
#                     "2017-01-02",
#                     6444
#                 ],
#                 [
#                     "2017-01-03",
#                     18860
#                 ],
#                 [
#                     "2017-01-04",
#                     3517
#                 ],
#                 [
#                     "2017-01-05",
#                     9626
#                 ],
#                 [
#                     "2017-01-06",
#                     6053
#                 ],
#                 [
#                     "2017-01-07",
#                     18597
#                 ],
#                 [
#                     "2017-01-08",
#                     4006
#                 ],
#                 [
#                     "2017-01-09",
#                     10242
#                 ],
#                 [
#                     "2017-01-10",
#                     9315
#                 ],
#                 [
#                     "2017-01-11",
#                     2097
#                 ],
#                 [
#                     "2017-01-12",
#                     23297
#                 ],
#                 [
#                     "2017-01-13",
#                     21727
#                 ],
#                 [
#                     "2017-01-14",
#                     22510
#                 ],
#                 [
#                     "2017-01-15",
#                     1468
#                 ],
#                 [
#                     "2017-01-16",
#                     3359
#                 ],
#                 [
#                     "2017-01-17",
#                     20540
#                 ],
#                 [
#                     "2017-01-18",
#                     8603
#                 ],
#                 [
#                     "2017-01-19",
#                     10824
#                 ],
#                 [
#                     "2017-01-20",
#                     8051
#                 ],
#                 [
#                     "2017-01-21",
#                     17989
#                 ],
#                 [
#                     "2017-01-22",
#                     7958
#                 ],
#                 [
#                     "2017-01-23",
#                     12171
#                 ],
#                 [
#                     "2017-01-24",
#                     5104
#                 ],
#                 [
#                     "2017-01-25",
#                     9785
#                 ],
#                 [
#                     "2017-01-26",
#                     23722
#                 ],
#                 [
#                     "2017-01-27",
#                     17892
#                 ],
#                 [
#                     "2017-01-28",
#                     18462
#                 ],
#                 [
#                     "2017-01-29",
#                     5892
#                 ],
#                 [
#                     "2017-01-30",
#                     2737
#                 ],
#                 [
#                     "2017-01-31",
#                     23769
#                 ],
#                 [
#                     "2017-02-01",
#                     3394
#                 ],
#                 [
#                     "2017-02-02",
#                     19308
#                 ],
#                 [
#                     "2017-02-03",
#                     2994
#                 ],
#                 [
#                     "2017-02-04",
#                     14408
#                 ],
#                 [
#                     "2017-02-05",
#                     8386
#                 ],
#                 [
#                     "2017-02-06",
#                     10120
#                 ],
#                 [
#                     "2017-02-07",
#                     23006
#                 ],
#                 [
#                     "2017-02-08",
#                     4431
#                 ],
#                 [
#                     "2017-02-09",
#                     4869
#                 ],
#                 [
#                     "2017-02-10",
#                     3199
#                 ],
#                 [
#                     "2017-02-11",
#                     9283
#                 ],
#                 [
#                     "2017-02-12",
#                     12671
#                 ],
#                 [
#                     "2017-02-13",
#                     18833
#                 ],
#                 [
#                     "2017-02-14",
#                     11853
#                 ],
#                 [
#                     "2017-02-15",
#                     16656
#                 ],
#                 [
#                     "2017-02-16",
#                     16973
#                 ],
#                 [
#                     "2017-02-17",
#                     18470
#                 ],
#                 [
#                     "2017-02-18",
#                     12149
#                 ],
#                 [
#                     "2017-02-19",
#                     16755
#                 ],
#                 [
#                     "2017-02-20",
#                     6154
#                 ],
#                 [
#                     "2017-02-21",
#                     23439
#                 ],
#                 [
#                     "2017-02-22",
#                     7854
#                 ],
#                 [
#                     "2017-02-23",
#                     6723
#                 ],
#                 [
#                     "2017-02-24",
#                     22730
#                 ],
#                 [
#                     "2017-02-25",
#                     16116
#                 ],
#                 [
#                     "2017-02-26",
#                     1776
#                 ],
#                 [
#                     "2017-02-27",
#                     4309
#                 ],
#                 [
#                     "2017-02-28",
#                     13489
#                 ],
#                 [
#                     "2017-03-01",
#                     9628
#                 ],
#                 [
#                     "2017-03-02",
#                     16228
#                 ],
#                 [
#                     "2017-03-03",
#                     20718
#                 ],
#                 [
#                     "2017-03-04",
#                     9191
#                 ],
#                 [
#                     "2017-03-05",
#                     17410
#                 ],
#                 [
#                     "2017-03-06",
#                     13159
#                 ],
#                 [
#                     "2017-03-07",
#                     23621
#                 ],
#                 [
#                     "2017-03-08",
#                     19235
#                 ],
#                 [
#                     "2017-03-09",
#                     24525
#                 ],
#                 [

# %% [markdown]
# ## Geo(地理图表)

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

geo = (
        Geo()
        .add_schema(maptype="china")
        .add("geo", [list(z) for z in zip(Faker.provinces, Faker.values())])
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
        )
    )
#geo.render_notebook()

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.datasets import register_url

try:
    register_url("https://echarts-maps.github.io/echarts-china-counties-js/")
except Exception:
    import ssl

    ssl._create_default_https_context = ssl._create_unverified_context
    register_url("https://echarts-maps.github.io/echarts-china-counties-js/")

geo = (
    Geo()
    .add_schema(maptype="海淀区")
    .set_global_opts(title_opts=opts.TitleOpts(title="海淀区"))
)

#geo.render_notebook()

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

geo = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "",
        [("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)],
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "geo",
        [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=6, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines"))
)

#geo.render_notebook()

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

geo = (
    Geo()
    .add_schema(
        maptype="china",
        itemstyle_opts=opts.ItemStyleOpts(color="#323c48", border_color="#111"),
    )
    .add(
        "",
        [("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)],
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "geo",
        [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=6, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines-background"))   
)

#geo.render_notebook()

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
from pyecharts.globals import ChartType

geo = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "geo",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        type_=ChartType.EFFECT_SCATTER,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-EffectScatter"))
)

#geo.render_notebook()
